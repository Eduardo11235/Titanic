# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import plotly.offline as py 
py.init_notebook_mode(connected=True) 
import plotly.graph_objs as go 
import plotly.tools as tls 
import warnings
from collections import Counter
import plotly.express as px

import re
import time
import math
from datetime import datetime as dt

from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,mean_squared_error,r2_score,mean_absolute_error
from sklearn.model_selection import train_test_split

pd.set_option('display.max_colwidth', None)

plt.style.use('dark_background')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from sklearn.metrics import roc_curve,roc_auc_score,precision_recall_curve
import warnings
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline
from pylab import rcParams
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV,StratifiedKFold,RandomizedSearchCV

# %matplotlib inline
rcParams['figure.figsize'] = 10, 6
warnings.filterwarnings('ignore')
sns.set(style="darkgrid")

# %%
df_test_sol = pd.read_csv('gender_submission.csv')
df_test_sol
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df_test = df_test.merge(df_test_sol,how='inner',on=['PassengerId'])
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#      Survived
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         0
# 417         0
#
# [418 rows x 12 columns]

# %%
df_train = pd.read_csv('train.csv')
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male  26.0      0
# 890                                  Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df_combine = [df_train,df_test]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
#  11  Survived     418 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 42.5+ KB

# %%
df_train.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
df_test.isnull().mean()
# Out:
# PassengerId    0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.205742
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.002392
# Cabin          0.782297
# Embarked       0.000000
# Survived       0.000000
# dtype: float64

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   418.000000  418.000000  332.000000  418.000000  418.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344
# std     120.810458    0.841838   14.181209    0.896760    0.981429
# min     892.000000    1.000000    0.170000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000
#
#              Fare    Survived
# count  417.000000  418.000000
# mean    35.627188    0.363636
# std     55.907576    0.481622
# min      0.000000    0.000000
# 25%      7.895800    0.000000
# 50%     14.454200    0.000000
# 75%     31.500000    1.000000
# max    512.329200    1.000000

# %%
df_train['Title'] = df_train['Name'].str.split('.',expand=True)[0].str.split(',',expand=True)[1].str.strip()
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male  26.0      0
# 890                                  Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Title
# 0        0         A/5 21171   7.2500   NaN        S    Mr
# 1        0          PC 17599  71.2833   C85        C   Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3        0            113803  53.1000  C123        S   Mrs
# 4        0            373450   8.0500   NaN        S    Mr
# ..     ...               ...      ...   ...      ...   ...
# 886      0            211536  13.0000   NaN        S   Rev
# 887      0            112053  30.0000   B42        S  Miss
# 888      2        W./C. 6607  23.4500   NaN        S  Miss
# 889      0            111369  30.0000  C148        C    Mr
# 890      0            370376   7.7500   NaN        Q    Mr
#
# [891 rows x 13 columns]

# %%
df_test['Title'] = df_test['Name'].str.split('.',expand=True)[0].str.split(',',expand=True)[1].str.strip()
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#      Survived   Title
# 0           0      Mr
# 1           1     Mrs
# 2           0      Mr
# 3           0      Mr
# 4           1     Mrs
# ..        ...     ...
# 413         0      Mr
# 414         1    Dona
# 415         0      Mr
# 416         0      Mr
# 417         0  Master
#
# [418 rows x 13 columns]

# %%
df_train['Title'].value_counts(normalize=True,dropna=True)
# Out:
# Mr              0.580247
# Miss            0.204265
# Mrs             0.140292
# Master          0.044893
# Dr              0.007856
# Rev             0.006734
# Mlle            0.002245
# Major           0.002245
# Col             0.002245
# the Countess    0.001122
# Capt            0.001122
# Ms              0.001122
# Sir             0.001122
# Lady            0.001122
# Mme             0.001122
# Don             0.001122
# Jonkheer        0.001122
# Name: Title, dtype: float64

# %%
df_test['Title'].value_counts(normalize=True,dropna=True)
# Out:
# Mr        0.574163
# Miss      0.186603
# Mrs       0.172249
# Master    0.050239
# Col       0.004785
# Rev       0.004785
# Ms        0.002392
# Dr        0.002392
# Dona      0.002392
# Name: Title, dtype: float64

# %% [markdown]
# ***
# *Now let's full the empty spaces*

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# Title            0
# dtype: int64

# %%
df_train_age = df_train.groupby(['Title'])['Age'].agg(['mean','median']).reset_index()
df_train_age.rename(columns={'mean':'Age Mean','median':'Age Median'},inplace=True)

# %%
df_train2 = df_train.merge(df_train_age,on='Title',how='left')
df_train2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male  26.0      0
# 890                                  Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Title   Age Mean  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr  32.368090
# 1        0          PC 17599  71.2833   C85        C   Mrs  35.898148
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss  21.773973
# 3        0            113803  53.1000  C123        S   Mrs  35.898148
# 4        0            373450   8.0500   NaN        S    Mr  32.368090
# ..     ...               ...      ...   ...      ...   ...        ...
# 886      0            211536  13.0000   NaN        S   Rev  43.166667
# 887      0            112053  30.0000   B42        S  Miss  21.773973
# 888      2        W./C. 6607  23.4500   NaN        S  Miss  21.773973
# 889      0            111369  30.0000  C148        C    Mr  32.368090
# 890      0            370376   7.7500   NaN        Q    Mr  32.368090
#
#      Age Median
# 0          30.0
# 1          35.0
# 2          21.0
# 3          35.0
# 4          30.0
# ..          ...
# 886        46.5
# 887        21.0
# 888        21.0
# 889        30.0
# 890        30.0
#
# [891 rows x 15 columns]

# %%
df_train2['Age'].fillna(df_train2['Age Median'],inplace=True)
df_train2.drop(columns=['Age Mean','Age Median'],inplace=True)

# %%
df_train2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
df_test_age = df_test.groupby(['Title'])['Age'].agg(['mean','median']).reset_index()
df_test_age.rename(columns={'mean':'Age Mean','median':'Age Median'},inplace=True)

# %%
df_test2 = df_test.merge(df_test_age,on='Title',how='left')
df_test2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#      Survived   Title   Age Mean  Age Median
# 0           0      Mr  32.000000        28.5
# 1           1     Mrs  38.903226        36.5
# 2           0      Mr  32.000000        28.5
# 3           0      Mr  32.000000        28.5
# 4           1     Mrs  38.903226        36.5
# ..        ...     ...        ...         ...
# 413         0      Mr  32.000000        28.5
# 414         1    Dona  39.000000        39.0
# 415         0      Mr  32.000000        28.5
# 416         0      Mr  32.000000        28.5
# 417         0  Master   7.406471         7.0
#
# [418 rows x 15 columns]

# %%
df_test2['Age'].fillna(df_test2['Age Median'],inplace=True)
df_test2.drop(columns=['Age Mean','Age Median'],inplace=True)

# %%
df_test2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              1
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# Title            0
# dtype: int64

# %%
df_test2[df_test2['Age'].isnull()]
# Out:
#     PassengerId  Pclass                     Name     Sex  Age  SibSp  Parch  \
# 88          980       3  O'Donoghue, Ms. Bridget  female  NaN      0      0
#
#     Ticket  Fare Cabin Embarked  Survived Title
# 88  364856  7.75   NaN        Q         1    Ms

# %%
df_test2['Age'].fillna(round(df_test2[(df_test2['Sex']=='female')&(df_test['Pclass']==3)&(df_test['Embarked']=='Q')]['Age'].mean(),1),inplace=True)

# %%
df_test2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male  28.5      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male  28.5      0      0              359309    8.0500   NaN        S
# 417    male   7.0      1      1                2668   22.3583   NaN        C
#
#      Survived   Title
# 0           0      Mr
# 1           1     Mrs
# 2           0      Mr
# 3           0      Mr
# 4           1     Mrs
# ..        ...     ...
# 413         0      Mr
# 414         1    Dona
# 415         0      Mr
# 416         0      Mr
# 417         0  Master
#
# [418 rows x 13 columns]

# %%
df_test2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# Title            0
# dtype: int64

# %%
df_train2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
df_train_embark = df_train2.groupby(['Embarked','Title'])['Title'].agg(['count']).reset_index()
df_train_embark
#df_age.rename(columns={'mean':'Age Mean','median':'Age Median'},inplace=True)
# Out:
#    Embarked         Title  count
# 0         C           Col      1
# 1         C           Don      1
# 2         C            Dr      2
# 3         C          Lady      1
# 4         C        Master      5
# 5         C          Miss     38
# 6         C          Mlle      2
# 7         C           Mme      1
# 8         C            Mr     85
# 9         C           Mrs     31
# 10        C           Sir      1
# 11        Q            Dr      1
# 12        Q        Master      4
# 13        Q          Miss     33
# 14        Q            Mr     35
# 15        Q           Mrs      3
# 16        Q           Rev      1
# 17        S          Capt      1
# 18        S           Col      1
# 19        S            Dr      4
# 20        S      Jonkheer      1
# 21        S         Major      2
# 22        S        Master     31
# 23        S          Miss    110
# 24        S            Mr    397
# 25        S           Mrs     90
# 26        S            Ms      1
# 27        S           Rev      5
# 28        S  the Countess      1

# %%
df_train_embark2 = df_train_embark.groupby('Title').max().reset_index()
df_train_embark2.rename(columns={'count':'Max Num','Embarked':'Missing Embarked'},inplace=True)
df_train_embark2
# Out:
#            Title Missing Embarked  Max Num
# 0           Capt                S        1
# 1            Col                S        1
# 2            Don                C        1
# 3             Dr                S        4
# 4       Jonkheer                S        1
# 5           Lady                C        1
# 6          Major                S        2
# 7         Master                S       31
# 8           Miss                S      110
# 9           Mlle                C        2
# 10           Mme                C        1
# 11            Mr                S      397
# 12           Mrs                S       90
# 13            Ms                S        1
# 14           Rev                S        5
# 15           Sir                C        1
# 16  the Countess                S        1

# %%
df_train3 = df_train2.merge(df_train_embark2,on='Title',how='left')
df_train3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female  21.0      1
# 889                                Behr, Mr. Karl Howell    male  26.0      0
# 890                                  Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Title Missing Embarked  \
# 0        0         A/5 21171   7.2500   NaN        S    Mr                S
# 1        0          PC 17599  71.2833   C85        C   Mrs                S
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss                S
# 3        0            113803  53.1000  C123        S   Mrs                S
# 4        0            373450   8.0500   NaN        S    Mr                S
# ..     ...               ...      ...   ...      ...   ...              ...
# 886      0            211536  13.0000   NaN        S   Rev                S
# 887      0            112053  30.0000   B42        S  Miss                S
# 888      2        W./C. 6607  23.4500   NaN        S  Miss                S
# 889      0            111369  30.0000  C148        C    Mr                S
# 890      0            370376   7.7500   NaN        Q    Mr                S
#
#      Max Num
# 0        397
# 1         90
# 2        110
# 3         90
# 4        397
# ..       ...
# 886        5
# 887      110
# 888      110
# 889      397
# 890      397
#
# [891 rows x 15 columns]

# %%
df_train3['Embarked'].fillna(df_train3['Missing Embarked'],inplace=True)
df_train3.drop(columns=['Missing Embarked','Max Num'],inplace=True)

# %% [markdown]
# Since there's not missing values in the column Embarked for the test dataset, we don't need to make other adjusment. How ever there's a missing

# %%
df_test2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# Title            0
# dtype: int64

# %%
df_test2[df_test2['Fare'].isnull()]
# Out:
#      PassengerId  Pclass                Name   Sex   Age  SibSp  Parch Ticket  \
# 152         1044       3  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      Fare Cabin Embarked  Survived Title
# 152   NaN   NaN        S         0    Mr

# %%
df_test2['Fare'].fillna(round(df_test2[(df_test2['Sex']=='male')&(df_test2['Pclass']==3)&(df_test2['Embarked']=='S')&(df_test2['Title']=='Mr')]['Fare'].mean(),1),inplace=True)

# %%
df_test2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# Survived         0
# Title            0
# dtype: int64

# %% [markdown]
# # Drop useless columns

# %%
df_train3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female  21.0      1
# 889                                Behr, Mr. Karl Howell    male  26.0      0
# 890                                  Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Title
# 0        0         A/5 21171   7.2500   NaN        S    Mr
# 1        0          PC 17599  71.2833   C85        C   Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3        0            113803  53.1000  C123        S   Mrs
# 4        0            373450   8.0500   NaN        S    Mr
# ..     ...               ...      ...   ...      ...   ...
# 886      0            211536  13.0000   NaN        S   Rev
# 887      0            112053  30.0000   B42        S  Miss
# 888      2        W./C. 6607  23.4500   NaN        S  Miss
# 889      0            111369  30.0000  C148        C    Mr
# 890      0            370376   7.7500   NaN        Q    Mr
#
# [891 rows x 13 columns]

# %%
df_train3.drop(columns=['PassengerId','Cabin','Ticket','Name'],inplace=True)

# %%
df_test2.drop(columns=['PassengerId','Cabin','Ticket','Name'],inplace=True)

# %%
df_train3['Age'] = df_train3['Age'].astype('int')
df_test2['Age'] = df_test2['Age'].astype('int')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Preprocessing

# %%
df_train3['Gender_Men'] = df_train3['Sex'].apply(lambda x: 1 if x=='male' else 0)
df_train3.drop(columns=['Sex'],inplace=True)
df_train3
# Out:
#      Survived  Pclass  Age  SibSp  Parch     Fare Embarked Title  Gender_Men
# 0           0       3   22      1      0   7.2500        S    Mr           1
# 1           1       1   38      1      0  71.2833        C   Mrs           0
# 2           1       3   26      0      0   7.9250        S  Miss           0
# 3           1       1   35      1      0  53.1000        S   Mrs           0
# 4           0       3   35      0      0   8.0500        S    Mr           1
# ..        ...     ...  ...    ...    ...      ...      ...   ...         ...
# 886         0       2   27      0      0  13.0000        S   Rev           1
# 887         1       1   19      0      0  30.0000        S  Miss           0
# 888         0       3   21      1      2  23.4500        S  Miss           0
# 889         1       1   26      0      0  30.0000        C    Mr           1
# 890         0       3   32      0      0   7.7500        Q    Mr           1
#
# [891 rows x 9 columns]

# %%
df_test2['Gender_Men'] = df_test2['Sex'].apply(lambda x: 1 if x=='male' else 0)
df_test2.drop(columns=['Sex'],inplace=True)
df_test2
# Out:
#      Pclass  Age  SibSp  Parch      Fare Embarked  Survived   Title  \
# 0         3   34      0      0    7.8292        Q         0      Mr
# 1         3   47      1      0    7.0000        S         1     Mrs
# 2         2   62      0      0    9.6875        Q         0      Mr
# 3         3   27      0      0    8.6625        S         0      Mr
# 4         3   22      1      1   12.2875        S         1     Mrs
# ..      ...  ...    ...    ...       ...      ...       ...     ...
# 413       3   28      0      0    8.0500        S         0      Mr
# 414       1   39      0      0  108.9000        C         1    Dona
# 415       3   38      0      0    7.2500        S         0      Mr
# 416       3   28      0      0    8.0500        S         0      Mr
# 417       3    7      1      1   22.3583        C         0  Master
#
#      Gender_Men
# 0             1
# 1             0
# 2             1
# 3             1
# 4             0
# ..          ...
# 413           1
# 414           0
# 415           1
# 416           1
# 417           1
#
# [418 rows x 9 columns]

# %%
A = set(df_train3['Title'])
A
# Out:
# {'Capt',
#  'Col',
#  'Don',
#  'Dr',
#  'Jonkheer',
#  'Lady',
#  'Major',
#  'Master',
#  'Miss',
#  'Mlle',
#  'Mme',
#  'Mr',
#  'Mrs',
#  'Ms',
#  'Rev',
#  'Sir',
#  'the Countess'}

# %%
B = set(df_test2['Title'])
B
# Out:
# {'Col', 'Dona', 'Dr', 'Master', 'Miss', 'Mr', 'Mrs', 'Ms', 'Rev'}

# %%
B.difference(A)
# Out:
# {'Dona'}

# %%
df_test3 = df_test2.drop(df_test2[df_test2['Title'] == 'Dona'].index)
df_test3.reset_index(drop=True,inplace=True)
# Out:
#      Pclass  Age  SibSp  Parch     Fare Embarked  Survived   Title  Gender_Men
# 0         3   34      0      0   7.8292        Q         0      Mr           1
# 1         3   47      1      0   7.0000        S         1     Mrs           0
# 2         2   62      0      0   9.6875        Q         0      Mr           1
# 3         3   27      0      0   8.6625        S         0      Mr           1
# 4         3   22      1      1  12.2875        S         1     Mrs           0
# ..      ...  ...    ...    ...      ...      ...       ...     ...         ...
# 412       3   28      0      0   7.7750        S         1    Miss           0
# 413       3   28      0      0   8.0500        S         0      Mr           1
# 415       3   38      0      0   7.2500        S         0      Mr           1
# 416       3   28      0      0   8.0500        S         0      Mr           1
# 417       3    7      1      1  22.3583        C         0  Master           1
#
# [417 rows x 9 columns]

# %%
# Importamos la biblioteca sklearn
from sklearn.preprocessing import OrdinalEncoder

# Creamos un objeto OrdinalEncoder()
encoder = OrdinalEncoder()

# Asignamos los valores numéricos a las categorías
df_train3["Title Ordinal"] = encoder.fit_transform(df_train3["Title"].values.reshape(-1, 1))

df_test3["Title Ordinal"] = encoder.transform(df_test3["Title"].values.reshape(-1, 1))

# %%
# Creamos un objeto OrdinalEncoder()
encoder = OrdinalEncoder()

# Asignamos los valores numéricos a las categorías
df_train3["Title Ordinal"] = encoder.fit_transform(df_train3["Title"].values.reshape(-1, 1))

df_test3["Title Ordinal"] = encoder.transform(df_test3["Title"].values.reshape(-1, 1))

# %%
df_train3.drop(columns=['Title'],inplace=True)
df_test3.drop(columns=['Title'],inplace=True)

# %%
df_test3
# Out:
#      Pclass  Age  SibSp  Parch     Fare Embarked  Survived  Gender_Men  \
# 0         3   34      0      0   7.8292        Q         0           1
# 1         3   47      1      0   7.0000        S         1           0
# 2         2   62      0      0   9.6875        Q         0           1
# 3         3   27      0      0   8.6625        S         0           1
# 4         3   22      1      1  12.2875        S         1           0
# ..      ...  ...    ...    ...      ...      ...       ...         ...
# 412       3   28      0      0   7.7750        S         1           0
# 413       3   28      0      0   8.0500        S         0           1
# 414       3   38      0      0   7.2500        S         0           1
# 415       3   28      0      0   8.0500        S         0           1
# 416       3    7      1      1  22.3583        C         0           1
#
#      Title Ordinal
# 0             11.0
# 1             12.0
# 2             11.0
# 3             11.0
# 4             12.0
# ..             ...
# 412            8.0
# 413           11.0
# 414           11.0
# 415           11.0
# 416            7.0
#
# [417 rows x 9 columns]

# %%
df_test3 = pd.get_dummies(df_test3, columns=['Embarked'],drop_first=True)
df_test3
# Out:
#      Pclass  Age  SibSp  Parch     Fare  Survived  Gender_Men  Title Ordinal  \
# 0         3   34      0      0   7.8292         0           1           11.0
# 1         3   47      1      0   7.0000         1           0           12.0
# 2         2   62      0      0   9.6875         0           1           11.0
# 3         3   27      0      0   8.6625         0           1           11.0
# 4         3   22      1      1  12.2875         1           0           12.0
# ..      ...  ...    ...    ...      ...       ...         ...            ...
# 412       3   28      0      0   7.7750         1           0            8.0
# 413       3   28      0      0   8.0500         0           1           11.0
# 414       3   38      0      0   7.2500         0           1           11.0
# 415       3   28      0      0   8.0500         0           1           11.0
# 416       3    7      1      1  22.3583         0           1            7.0
#
#      Embarked_Q  Embarked_S
# 0             1           0
# 1             0           1
# 2             1           0
# 3             0           1
# 4             0           1
# ..          ...         ...
# 412           0           1
# 413           0           1
# 414           0           1
# 415           0           1
# 416           0           0
#
# [417 rows x 10 columns]

# %%
df_train3 = pd.get_dummies(df_train3, columns=['Embarked'],drop_first=True)
df_train3
# Out:
#      Survived  Pclass  Age  SibSp  Parch     Fare  Gender_Men  Title Ordinal  \
# 0           0       3   22      1      0   7.2500           1           11.0
# 1           1       1   38      1      0  71.2833           0           12.0
# 2           1       3   26      0      0   7.9250           0            8.0
# 3           1       1   35      1      0  53.1000           0           12.0
# 4           0       3   35      0      0   8.0500           1           11.0
# ..        ...     ...  ...    ...    ...      ...         ...            ...
# 886         0       2   27      0      0  13.0000           1           14.0
# 887         1       1   19      0      0  30.0000           0            8.0
# 888         0       3   21      1      2  23.4500           0            8.0
# 889         1       1   26      0      0  30.0000           1           11.0
# 890         0       3   32      0      0   7.7500           1           11.0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 10 columns]

# %%
df_train3.dtypes
# Out:
# Survived           int64
# Pclass             int64
# Age                int64
# SibSp              int64
# Parch              int64
# Fare             float64
# Gender_Men         int64
# Title Ordinal    float64
# Embarked_Q         uint8
# Embarked_S         uint8
# dtype: object

# %%
X_train,y_train = df_train3.drop(columns=['Survived']),df_train3['Survived']

# %%
X_test,y_test = df_test3.drop(columns=['Survived']),df_test3['Survived']

# %%
#X_train,X_val,y_train,y_val =train_test_split(X_train,y_train,stratify=y_train,random_state=100,test_size=0.35)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

columns = ['Fare','Age','SibSp','Parch']

X_train[columns] = scaler.fit_transform(X_train[columns])
X_train
# Out:
#      Pclass     Age  SibSp     Parch      Fare  Gender_Men  Title Ordinal  \
# 0         3  0.2750  0.125  0.000000  0.014151           1           11.0
# 1         1  0.4750  0.125  0.000000  0.139136           0           12.0
# 2         3  0.3250  0.000  0.000000  0.015469           0            8.0
# 3         1  0.4375  0.125  0.000000  0.103644           0           12.0
# 4         3  0.4375  0.000  0.000000  0.015713           1           11.0
# ..      ...     ...    ...       ...       ...         ...            ...
# 886       2  0.3375  0.000  0.000000  0.025374           1           14.0
# 887       1  0.2375  0.000  0.000000  0.058556           0            8.0
# 888       3  0.2625  0.125  0.333333  0.045771           0            8.0
# 889       1  0.3250  0.000  0.000000  0.058556           1           11.0
# 890       3  0.4000  0.000  0.000000  0.015127           1           11.0
#
#      Embarked_Q  Embarked_S
# 0             0           1
# 1             0           0
# 2             0           1
# 3             0           1
# 4             0           1
# ..          ...         ...
# 886           0           1
# 887           0           1
# 888           0           1
# 889           0           0
# 890           1           0
#
# [891 rows x 9 columns]

# %%
X_test[columns] = scaler.transform(X_test[columns])
X_test
# Out:
#      Pclass     Age  SibSp     Parch      Fare  Gender_Men  Title Ordinal  \
# 0         3  0.4250  0.000  0.000000  0.015282           1           11.0
# 1         3  0.5875  0.125  0.000000  0.013663           0           12.0
# 2         2  0.7750  0.000  0.000000  0.018909           1           11.0
# 3         3  0.3375  0.000  0.000000  0.016908           1           11.0
# 4         3  0.2750  0.125  0.166667  0.023984           0           12.0
# ..      ...     ...    ...       ...       ...         ...            ...
# 412       3  0.3500  0.000  0.000000  0.015176           0            8.0
# 413       3  0.3500  0.000  0.000000  0.015713           1           11.0
# 414       3  0.4750  0.000  0.000000  0.014151           1           11.0
# 415       3  0.3500  0.000  0.000000  0.015713           1           11.0
# 416       3  0.0875  0.125  0.166667  0.043640           1            7.0
#
#      Embarked_Q  Embarked_S
# 0             1           0
# 1             0           1
# 2             1           0
# 3             0           1
# 4             0           1
# ..          ...         ...
# 412           0           1
# 413           0           1
# 414           0           1
# 415           0           1
# 416           0           0
#
# [417 rows x 9 columns]

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE

print(f"Training Set before over sampling:\n {Counter(y_train)} \n")

sm = SMOTE(random_state=100)
X_train_res,y_train_res = sm.fit_resample(X_train,y_train)

print(f"Training Set after over sampling:\n {Counter(y_train_res)}")
# Out:
# Training Set before over sampling:
#  Counter({0: 549, 1: 342})
#
# Training Set after over sampling:
#  Counter({0: 549, 1: 549})

# %% [markdown]
# # Fuctions

# %%
from sklearn.metrics import roc_curve,roc_auc_score,precision_recall_curve
import warnings
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline
from pylab import rcParams
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV,StratifiedKFold,RandomizedSearchCV

# %matplotlib inline
rcParams['figure.figsize'] = 10, 6
warnings.filterwarnings('ignore')
sns.set(style="darkgrid")

def plotly_auc_roc_curve(model,X,y):
    
    pred_y_proba = model.predict_proba(X)[:,1]
    fpr,tpr,thresholds = roc_curve(y,pred_y_proba)
    auc = roc_auc_score(y,pred_y_proba)
    
    trace0 = go.Scatter(x=fpr, y=tpr,name='ROC Curve',marker=dict(color='#3D9970'),mode='lines')
    trace1 = go.Scatter(x=[0,1], y=[0,1],name='Base',marker=dict(color='#FF4136'),mode='lines')
    
    data = [trace0,trace1]

    layout=go.Layout(
                    xaxis=dict(title='False Positive Rate'),
                    yaxis=dict(title='True Positive Rate'),
                    title='ROC Curve')


    fig = go.Figure(data=data,layout=layout)

    fig.update_layout(template='plotly_dark',legend_title_text='AUC:  ' + str((auc*100).round(2)) +'%', width=1000, height=600)
    
    fig.show('svg')
    
    pass

def plotly_auc_roc_curve2(model,X,y):
    
    pred_y_proba = model.predict_proba(X)[:,1]
    fpr,tpr,thresholds = roc_curve(y,pred_y_proba)
    auc = roc_auc_score(y,pred_y_proba)
    
    trace0 = go.Scatter(x=thresholds, y=tpr,name='True Positive Rate',marker=dict(color='#3D9970'),mode='lines')
    trace1 = go.Scatter(x=thresholds, y=(1-fpr),name='False Positive Rate',marker=dict(color='#FF4136'),mode='lines')
    #trace1 = go.Scatter(x=[0,1], y=[0,1],name='Base',marker=dict(color='#FF4136'),mode='lines')
    
    data = [trace0,trace1]

    layout=go.Layout(
                    xaxis=dict(title='Thresholds'),
                    yaxis=dict(title='Rate'),
                    title='True Positive Rate vs False Positive Rate')


    fig = go.Figure(data=data,layout=layout)

    fig.update_layout(template='plotly_dark',legend_title_text='AUC:  ' + str((auc*100).round(2)) +'%', width=1000, height=600)
    
    fig.show('svg')
    
    pass

def plotly_precision_recall_curve(model,X,y):
    
    pred_y_proba = model.predict_proba(X)[:,1]
    precision,recall,thresholds = precision_recall_curve(y,pred_y_proba)
    
    trace0 = go.Scatter(x=precision, y=recall,name='ROC Curve',marker=dict(color='#1f77b4'),mode='lines')
    
    
    data = [trace0]

    layout=go.Layout(
                    xaxis=dict(title='Precision Score'),
                    yaxis=dict(title='Recall Score'),
                    title='Precision Recall Curve')


    fig = go.Figure(data=data,layout=layout)

    fig.update_layout(template='plotly_dark', width=1000, height=600)
    #fig.update_layout(legend_title_text='Trend')
    
    fig.show('svg')
    
    pass

def plotly_precision_recall_curve2(model,X,y):
    
    pred_y_proba = model.predict_proba(X)[:,1]
    precision,recall,thresholds = precision_recall_curve(y,pred_y_proba)
    
    #trace0 = go.Scatter(x=precision, y=recall,name='ROC Curve',marker=dict(color='#3D9970'),mode='lines')
    trace0 = go.Scatter(x=thresholds, y=precision,name='Precision',marker=dict(color='#FF4136'),mode='lines')
    trace1 = go.Scatter(x=thresholds, y=recall,name='Recall',marker=dict(color='#3D9970'),mode='lines')
    trace2 = go.Scatter(x=thresholds, y = 2*( (recall*precision)/(recall+precision) ), name='F1 score' ,marker=dict(color='#1f77b4') , mode='lines' )
    
    data = [trace0,trace1,trace2]

    layout=go.Layout(
                    xaxis=dict(title='Threshold'),
               
                    title='Precision Recall Threshold')


    fig = go.Figure(data=data,layout=layout)

    fig.update_layout(template='plotly_dark',yaxis_range=[0,1],xaxis_range=[0,1], width=1000, height=600)
    
    #fig.update_layout(yaxis_range=[-4,4])
    #fig.update_layout(legend_title_text='Trend')
    
    fig.show('svg')
    
    pass

def new_threshold(model,threshold,X):
    
    import numpy as np
    
    y_pred = model.predict_proba(X)[:,1]
    
    list_new = []
    
    for y_value in y_pred:
        
        if y_value >= threshold:
            
            list_new.append(1)
            
        else:
            
            list_new.append(0)
            
    return np.array(list_new)

def plot_best_models2(models_list,str_model_name,X,y):
    
    colors_list=['#636EFA','#00CC96','#AB63FA','#FFA15A', '#19D3F3', '#FF6692', '#B6E880', '#FF97FF', '#FECB52']
    
    data = []
    
    for i in range(len(models_list)):
        
            pred_y_proba = models_list[i].predict_proba(X)[:,1]
            fpr,tpr,thresholds = roc_curve(y,pred_y_proba)
            auc = roc_auc_score(y,pred_y_proba)
            
            data.append(go.Scatter(x=fpr, y=tpr,name= str_model_name[i] +'; AUC:'+ str((auc*100).round(2)) +'%',marker=dict(color=colors_list[i]),mode='lines'))

    data.append(go.Scatter(x=[0,1], y=[0,1],name='Base',marker=dict(color='#FF4136'),mode='lines'))
            
    layout=go.Layout(
                    xaxis=dict(title='False Positive Rate'),
                    yaxis=dict(title='True Positive Rate'),
                    title='ROC Curves for different Models')
    
    fig = go.Figure(data=data,layout=layout)

    fig.update_layout(template='plotly_dark',legend_title_text='Different Algorithms', width=1100, height=800)
    
    fig.show('svg')
    
    
    data = []
    
    for i in range(len(models_list)):
        
            pred_y_proba = models_list[i].predict_proba(X)[:,1]
            precision,recall,thresholds = precision_recall_curve(y,pred_y_proba)
            auc = roc_auc_score(y,pred_y_proba)
            
            data.append(go.Scatter(x=thresholds, y = 2*( (recall*precision)/(recall+precision) ),name= 'F1 score '+ str_model_name[i] +'; AUC:'+ str((auc*100).round(2)) +'%',marker=dict(color=colors_list[i]),mode='lines'))
            
    layout=go.Layout(
                    xaxis=dict(title='Threshold'),
                    yaxis=dict(title='F1 Score Rate'),
                    title='F1 Score / Threshold for Different Models')
    
    fig = go.Figure(data=data,layout=layout)

    fig.update_layout(template='plotly_dark',legend_title_text='Different Algorithms', width=1100, height=800)
    
    fig.show('svg')

# %% [markdown]
# ***
# ***
# # Algorithms

# %% [markdown]
# ## KNeighbors Classifier

# %%
start = time.process_time()
real_time = dt.now()

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train,y_train)

pred_val = knn.predict(X_test)


print(f"Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Validation Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(knn,X_test,y_test)

plotly_precision_recall_curve(knn,X_test,y_test)

plotly_precision_recall_curve2(knn,X_test,y_test)
# Out:
# Confusion Matrix of Validation Set:
#
#  [[245  21]
#  [ 40 111]]
#
# Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       266
#            1       0.84      0.74      0.78       151
#
#     accuracy                           0.85       417
#    macro avg       0.85      0.83      0.84       417
# weighted avg       0.85      0.85      0.85       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
start = time.process_time()
real_time = dt.now()

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train_res,y_train_res)

pred_val = knn.predict(X_test)


print(f"Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Validation Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(knn,X_test,y_test)

plotly_precision_recall_curve(knn,X_test,y_test)

plotly_precision_recall_curve2(knn,X_test,y_test)
# Out:
# Confusion Matrix of Validation Set:
#
#  [[215  51]
#  [ 20 131]]
#
# Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.81      0.86       266
#            1       0.72      0.87      0.79       151
#
#     accuracy                           0.83       417
#    macro avg       0.82      0.84      0.82       417
# weighted avg       0.84      0.83      0.83       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
start = time.process_time()
real_time = dt.now()

model_knn_rand = KNeighborsClassifier()

params_knn_rand = { 'n_neighbors':[5,8,10,12,14]}

skf = StratifiedKFold(n_splits=5, random_state=42,shuffle=True)

from sklearn.model_selection import RandomizedSearchCV
random_search_knn_rand = RandomizedSearchCV(model_knn_rand,param_distributions=params_knn_rand,cv=skf,n_iter=5,scoring='f1_macro',n_jobs=-1, random_state=100)

random_search_knn_rand.fit(X_train_res,y_train_res)
print(random_search_knn_rand.best_params_)

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))
# Out:
# {'n_neighbors': 5}
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.05 minutes

# %%
start = time.process_time()
real_time = dt.now()

best_knn = KNeighborsClassifier(**random_search_knn_rand.best_params_)
best_knn.fit(X_train_res,y_train_res)

pred_val = best_knn.predict(X_test)


print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")


print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(best_knn,X_test,y_test)

plotly_precision_recall_curve(best_knn,X_test,y_test)

plotly_precision_recall_curve2(best_knn,X_test,y_test)
# Out:
# Confusion Matrix of Testing Set:
#
#  [[206  60]
#  [ 13 138]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85       266
#            1       0.70      0.91      0.79       151
#
#     accuracy                           0.82       417
#    macro avg       0.82      0.84      0.82       417
# weighted avg       0.85      0.82      0.83       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %% [markdown]
# ***
# ## Logistic Regression

# %%
start = time.process_time()
real_time = dt.now()

from sklearn.linear_model import LogisticRegression

log = LogisticRegression(random_state=100,max_iter=1000)
log.fit(X_train,y_train)


pred_val = log.predict(X_test)


print(f"Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Validation Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(log,X_test,y_test)

plotly_precision_recall_curve(log,X_test,y_test)

plotly_precision_recall_curve2(log,X_test,y_test)
# Out:
# Confusion Matrix of Validation Set:
#
#  [[251  15]
#  [ 13 138]]
#
# Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       266
#            1       0.90      0.91      0.91       151
#
#     accuracy                           0.93       417
#    macro avg       0.93      0.93      0.93       417
# weighted avg       0.93      0.93      0.93       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
start = time.process_time()
real_time = dt.now()

model=LogisticRegression()

param_grid={   'max_iter':[1000,1500,3000,5000],'penalty':['l2','l1'], 'C': np.logspace(-4,4,20),'solver': ['lbfgs','netwon-cg','liblinear','sag','saga']  }

grid_search = GridSearchCV(model, param_grid, scoring="accuracy")
grid_search.fit(X_train,y_train)

print(grid_search.best_params_)

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))
# Out:
# {'C': 0.08858667904100823, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
#
#  The Process time taken by the model was 2.68 minutes
#
#  The Real time taken by the model was 0.67 minutes

# %%
start = time.process_time()
real_time = dt.now()

best_log = LogisticRegression(**grid_search.best_params_)
best_log.fit(X_train,y_train)

pred_val = best_log.predict(X_test)

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(best_log,X_test,y_test)

plotly_precision_recall_curve(best_log,X_test,y_test)

plotly_precision_recall_curve2(best_log,X_test,y_test)
# Out:
# Confusion Matrix of Testing Set:
#
#  [[266   0]
#  [ 25 126]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96       266
#            1       1.00      0.83      0.91       151
#
#     accuracy                           0.94       417
#    macro avg       0.96      0.92      0.93       417
# weighted avg       0.95      0.94      0.94       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
pred_val = best_log.predict(X_test)

pred_new = new_threshold(best_log,0.4,X_test)

print(f"Previous Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_test,pred_val)} \n")

print(f"New Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_test,pred_new)} \n")

print(f"Previous Classification Report of Validation Set: \n \n {classification_report(y_test,pred_val)}")

print(f"New Classification Report of Validation Set: \n \n {classification_report(y_test,pred_new)}")
# Out:
# Previous Confusion Matrix of Validation Set:
#
#  [[266   0]
#  [ 25 126]]
#
# New Confusion Matrix of Validation Set:
#
#  [[245  21]
#  [  0 151]]
#
# Previous Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96       266
#            1       1.00      0.83      0.91       151
#
#     accuracy                           0.94       417
#    macro avg       0.96      0.92      0.93       417
# weighted avg       0.95      0.94      0.94       417
#
# New Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96       266
#            1       0.88      1.00      0.93       151
#
#     accuracy                           0.95       417
#    macro avg       0.94      0.96      0.95       417
# weighted avg       0.96      0.95      0.95       417

# %% [markdown]
# ***
# Resample Data

# %%
start = time.process_time()
real_time = dt.now()

from sklearn.linear_model import LogisticRegression

log = LogisticRegression(random_state=100,max_iter=1000)
log.fit(X_train_res,y_train_res)


pred_val = log.predict(X_test)


print(f"Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Validation Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(log,X_test,y_test)


plotly_precision_recall_curve(log,X_test,y_test)

plotly_precision_recall_curve2(log,X_test,y_test)
# Out:
# Confusion Matrix of Validation Set:
#
#  [[229  37]
#  [  5 146]]
#
# Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92       266
#            1       0.80      0.97      0.87       151
#
#     accuracy                           0.90       417
#    macro avg       0.89      0.91      0.90       417
# weighted avg       0.91      0.90      0.90       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
start = time.process_time()
real_time = dt.now()

model=LogisticRegression()

param_grid={   'max_iter':[1000,1500,3000,5000],'penalty':['l2','l1'], 'C': np.logspace(-4,4,20),'solver': ['lbfgs','netwon-cg','liblinear','sag','saga']  }

grid_search = GridSearchCV(model, param_grid, scoring="accuracy")
grid_search.fit(X_train_res,y_train_res)

print(grid_search.best_params_)

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))
# Out:
# {'C': 1.623776739188721, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'saga'}
#
#  The Process time taken by the model was 2.76 minutes
#
#  The Real time taken by the model was 0.77 minutes

# %%
start = time.process_time()
real_time = dt.now()

best_log = LogisticRegression(**grid_search.best_params_)
best_log.fit(X_train_res,y_train_res)

pred_val = best_log.predict(X_test)

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(best_log,X_test,y_test)

plotly_precision_recall_curve(best_log,X_test,y_test)

plotly_precision_recall_curve2(best_log,X_test,y_test)
# Out:
# Confusion Matrix of Testing Set:
#
#  [[230  36]
#  [  5 146]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92       266
#            1       0.80      0.97      0.88       151
#
#     accuracy                           0.90       417
#    macro avg       0.89      0.92      0.90       417
# weighted avg       0.91      0.90      0.90       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
pred_val = best_log.predict(X_test)

pred_new = new_threshold(best_log,0.63,X_test)

print(f"Previous Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_test,pred_val)} \n")

print(f"New Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_test,pred_new)} \n")

print(f"Previous Classification Report of Validation Set: \n \n {classification_report(y_test,pred_val)}")

print(f"New Classification Report of Validation Set: \n \n {classification_report(y_test,pred_new)}")
# Out:
# Previous Confusion Matrix of Validation Set:
#
#  [[230  36]
#  [  5 146]]
#
# New Confusion Matrix of Validation Set:
#
#  [[253  13]
#  [ 16 135]]
#
# Previous Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92       266
#            1       0.80      0.97      0.88       151
#
#     accuracy                           0.90       417
#    macro avg       0.89      0.92      0.90       417
# weighted avg       0.91      0.90      0.90       417
#
# New Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       266
#            1       0.91      0.89      0.90       151
#
#     accuracy                           0.93       417
#    macro avg       0.93      0.92      0.92       417
# weighted avg       0.93      0.93      0.93       417

# %% [markdown]
# ## Random Forest Classifier

# %%
start = time.process_time()

real_time = dt.now()

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(random_state=100,n_estimators=100)
rfc.fit(X_train,y_train)

pred_val = rfc.predict(X_test)

print(f"Training score {rfc.score(X_train,y_train)} \n ")
print(f"Testing score {rfc.score(X_test,y_test)} \n ")

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(rfc,X_test,y_test)

plotly_precision_recall_curve(rfc,X_test,y_test)

plotly_precision_recall_curve2(rfc,X_test,y_test)
# Out:
# Training score 0.9809203142536476
#
# Testing score 0.8033573141486811
#
# Confusion Matrix of Testing Set:
#
#  [[217  49]
#  [ 33 118]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84       266
#            1       0.71      0.78      0.74       151
#
#     accuracy                           0.80       417
#    macro avg       0.79      0.80      0.79       417
# weighted avg       0.81      0.80      0.81       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
start = time.process_time()
real_time = dt.now()

model=RandomForestClassifier()

param_grid={    'n_estimators' : [100,125,150,175,200],
                'max_depth':[1,2,3,4,5,6],
                'random_state':[100],
                 'max_features':['sqrt','log2'],
                'class_weight':['balanced'] }

grid_search = GridSearchCV(model, param_grid, scoring="accuracy")
grid_search.fit(X_train,y_train)

print(grid_search.best_params_)

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))
# Out:
# {'class_weight': 'balanced', 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 125, 'random_state': 100}
#
#  The Process time taken by the model was 0.62 minutes
#
#  The Real time taken by the model was 0.62 minutes

# %%
start = time.process_time()
real_time = dt.now()

best_forest = RandomForestClassifier(**grid_search.best_params_)
best_forest.fit(X_train,y_train)

pred_val = best_forest.predict(X_test)

print(f"Training score {best_forest.score(X_train,y_train)} \n ")
print(f"Testing score {best_forest.score(X_test,y_test)} \n ")

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(best_forest,X_test,y_test)

plotly_precision_recall_curve(best_forest,X_test,y_test)

plotly_precision_recall_curve2(best_forest,X_test,y_test)
# Out:
# Training score 0.8742985409652076
#
# Testing score 0.9088729016786571
#
# Confusion Matrix of Testing Set:
#
#  [[238  28]
#  [ 10 141]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.96      0.89      0.93       266
#            1       0.83      0.93      0.88       151
#
#     accuracy                           0.91       417
#    macro avg       0.90      0.91      0.90       417
# weighted avg       0.91      0.91      0.91       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
for i,item in enumerate(best_forest.feature_importances_):
    print(" {0:s} : {1:.2f}".format(X_test.columns[i],item))
# Out:
#  Pclass : 0.13
#  Age : 0.11
#  SibSp : 0.06
#  Parch : 0.03
#  Fare : 0.16
#  Gender_Men : 0.35
#  Title Ordinal : 0.14
#  Embarked_Q : 0.01
#  Embarked_S : 0.02

# %% [markdown]
# ****
# Resample Data

# %%
start = time.process_time()

real_time = dt.now()

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(random_state=100,n_estimators=100)
rfc.fit(X_train_res,y_train_res)

pred_val = rfc.predict(X_test)

print(f"Training score {rfc.score(X_train,y_train)} \n ")
print(f"Testing score {rfc.score(X_test,y_test)} \n ")

print(f"Training score {rfc.score(X_train,y_train)} \n ")
print(f"Validation score {rfc.score(X_test,y_test)} \n ")

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(rfc,X_test,y_test)

plotly_precision_recall_curve(rfc,X_test,y_test)

plotly_precision_recall_curve2(rfc,X_test,y_test)
# Out:
# Training score 0.9809203142536476
#
# Testing score 0.7769784172661871
#
# Training score 0.9809203142536476
#
# Validation score 0.7769784172661871
#
# Confusion Matrix of Testing Set:
#
#  [[207  59]
#  [ 34 117]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82       266
#            1       0.66      0.77      0.72       151
#
#     accuracy                           0.78       417
#    macro avg       0.76      0.78      0.77       417
# weighted avg       0.79      0.78      0.78       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
start = time.process_time()
real_time = dt.now()

model=RandomForestClassifier()

param_grid={    'n_estimators' : [100,125,150,175,200],
                'max_depth':[1,2,3,4,5,6],
                'random_state':[100],
                 'max_features':['sqrt','log2'],
                'class_weight':['balanced'] }

grid_search = GridSearchCV(model, param_grid, scoring="accuracy")
grid_search.fit(X_train_res,y_train_res)

print(grid_search.best_params_)

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))
# Out:
# {'class_weight': 'balanced', 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 150, 'random_state': 100}
#
#  The Process time taken by the model was 0.64 minutes
#
#  The Real time taken by the model was 0.65 minutes

# %%
start = time.process_time()
real_time = dt.now()

best_forest = RandomForestClassifier(**grid_search.best_params_)
best_forest.fit(X_train,y_train)

pred_val = best_forest.predict(X_test)

print(f"Training score {best_forest.score(X_train,y_train)} \n ")
print(f"Testing score {best_forest.score(X_test,y_test)} \n ")

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(best_forest,X_test,y_test)

plotly_precision_recall_curve(best_forest,X_test,y_test)

plotly_precision_recall_curve2(best_forest,X_test,y_test)
# Out:
# Training score 0.8787878787878788
#
# Testing score 0.9016786570743405
#
# Confusion Matrix of Testing Set:
#
#  [[237  29]
#  [ 12 139]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       266
#            1       0.83      0.92      0.87       151
#
#     accuracy                           0.90       417
#    macro avg       0.89      0.91      0.90       417
# weighted avg       0.91      0.90      0.90       417
#
#
#  The Process time taken by the model was 0.0 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
for i,item in enumerate(best_forest.feature_importances_):
    print(" {0:s} : {1:.2f}".format(X_test.columns[i],item))
# Out:
#  Pclass : 0.13
#  Age : 0.11
#  SibSp : 0.06
#  Parch : 0.03
#  Fare : 0.16
#  Gender_Men : 0.35
#  Title Ordinal : 0.14
#  Embarked_Q : 0.01
#  Embarked_S : 0.02

# %% [markdown]
# ***
# ## XGBoost Classifier

# %%
start = time.process_time()
real_time = dt.now()

from xgboost import XGBClassifier

xgb = XGBClassifier(random_state=100)
xgb.fit(X_train,y_train)

pred_val = xgb.predict(X_test)

print(f"Training score {xgb.score(X_train,y_train)} \n ")
print(f"Testing score {xgb.score(X_test,y_test)} \n ")

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")


print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(xgb,X_test,y_test)

plotly_precision_recall_curve(xgb,X_test,y_test)

plotly_precision_recall_curve2(xgb,X_test,y_test)
# Out:
# Training score 0.9652076318742986
#
# Testing score 0.841726618705036
#
# Confusion Matrix of Testing Set:
#
#  [[231  35]
#  [ 31 120]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       266
#            1       0.77      0.79      0.78       151
#
#     accuracy                           0.84       417
#    macro avg       0.83      0.83      0.83       417
# weighted avg       0.84      0.84      0.84       417
#
#
#  The Process time taken by the model was 0.01 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
start = time.process_time()
real_time = dt.now()

model=XGBClassifier()

param_grid={    'learning_rate' : [0.05,0.1,0.15,0.2,0.25,0.3],
                                    'max_depth':[2,3,4,5],
                                    'min_child_weight':[1,3,5,7],
                                    'gamma':[0.0,0.1,0.2,0.3,0.4]}#,
                                   # 'max_delta_step':[0,1,2,3,4,5,10,50,100,1000],
                                    #'scale_pos_weight' : [1, 10, 75, 100, 1000]  }
           

grid_search = GridSearchCV(model, param_grid, scoring="accuracy")
grid_search.fit(X_train,y_train)

print(grid_search.best_params_)

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))
# Out:
# {'gamma': 0.1, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 3}
#
#  The Process time taken by the model was 14.62 minutes
#
#  The Real time taken by the model was 2.17 minutes

# %%
start = time.process_time()
real_time = dt.now()

best_forest = RandomForestClassifier(**grid_search.best_params_)
best_forest.fit(X_train,y_train)

pred_val = best_forest.predict(X_test)

print(f"Training score {best_forest.score(X_train,y_train)} \n ")
print(f"Testing score {best_forest.score(X_test,y_test)} \n ")

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(best_forest,X_test,y_test)

plotly_precision_recall_curve(best_forest,X_test,y_test)

plotly_precision_recall_curve2(best_forest,X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jk/86g29y8j0f7fr3xkq450p1j00000gn/T/ipykernel_1513/772478356.py in <module>
#       2 real_time = dt.now()
#       3
# ----> 4 best_forest = RandomForestClassifier(**grid_search.best_params_)
#       5 best_forest.fit(X_train,y_train)
#       6
#
# TypeError: __init__() got an unexpected keyword argument 'gamma'

# %% [markdown]
# ***
# Resample Data

# %%
start = time.process_time()
real_time = dt.now()

from xgboost import XGBClassifier

xgb = XGBClassifier(random_state=100)
xgb.fit(X_train_res,y_train_res)

pred_val = xgb.predict(X_val)


print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_val,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_val,pred_val)}")


print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(xgb,X_val,y_val)

plotly_precision_recall_curve(xgb,X_val,y_val)

plotly_precision_recall_curve2(xgb,X_val,y_val)
# Out:
# Confusion Matrix of Testing Set:
#
#  [[150   4]
#  [  5  91]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       154
#            1       0.96      0.95      0.95        96
#
#     accuracy                           0.96       250
#    macro avg       0.96      0.96      0.96       250
# weighted avg       0.96      0.96      0.96       250
#
#
#  The Process time taken by the model was 0.01 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %%
start = time.process_time()
real_time = dt.now()

model=XGBClassifier()

param_grid={    'learning_rate' : [0.05,0.1,0.15,0.2,0.25,0.3],
                                    'max_depth':[2,3,4,5],
                                    'min_child_weight':[1,3,5,7],
                                    'gamma':[0.0,0.1,0.2,0.3,0.4],
                                    'max_delta_step':[0,1,2,3,4,5,10,50,100,1000],
                                    'scale_pos_weight' : [1, 10, 75, 100, 1000]  }

grid_search = GridSearchCV(model, param_grid, scoring="accuracy")
grid_search.fit(X_train_res,y_train_res)

print(grid_search.best_params_)

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

# %%
start = time.process_time()
real_time = dt.now()

best_forest = RandomForestClassifier(**grid_search.best_params_)
best_forest.fit(X_train_res,y_train_res)

pred_val = best_forest.predict(X_test)

print(f"Training score {best_forest.score(X_train,y_train)} \n ")
print(f"Testing score {best_forest.score(X_test,y_test)} \n ")

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_test,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_test,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(best_forest,X_test,y_test)

plotly_precision_recall_curve(best_forest,X_test,y_test)

plotly_precision_recall_curve2(best_forest,X_test,y_test)

# %%
pred_val = xgb.predict(X_val)

pred_new = new_threshold(xgb,0.4,X_val)

print(f"Previous Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_val,pred_val)} \n")

print(f"New Confusion Matrix of Validation Set: \n \n {confusion_matrix(y_val,pred_new)} \n")

print(f"Previous Classification Report of Validation Set: \n \n {classification_report(y_val,pred_val)}")

print(f"New Classification Report of Validation Set: \n \n {classification_report(y_val,pred_new)}")
# Out:
# Previous Confusion Matrix of Validation Set:
#
#  [[150   4]
#  [  5  91]]
#
# New Confusion Matrix of Validation Set:
#
#  [[146   8]
#  [  3  93]]
#
# Previous Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       154
#            1       0.96      0.95      0.95        96
#
#     accuracy                           0.96       250
#    macro avg       0.96      0.96      0.96       250
# weighted avg       0.96      0.96      0.96       250
#
# New Classification Report of Validation Set:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       154
#            1       0.92      0.97      0.94        96
#
#     accuracy                           0.96       250
#    macro avg       0.95      0.96      0.95       250
# weighted avg       0.96      0.96      0.96       250

# %%
start = time.process_time()
real_time = dt.now()

from sklearn.model_selection import RandomizedSearchCV


model_xgb_rand = XGBClassifier()

params_xgb_rand = {
                              'learning_rate' : [0.05,0.1,0.15,0.2,0.25,0.3],
                                    'max_depth':[2,3,4,5],
                                    'min_child_weight':[1,3,5,7],
                                    'gamma':[0.0,0.1,0.2,0.3,0.4],
                                    'max_delta_step':[0,1,2,3,4,5,10,50,100,1000],
                                    'scale_pos_weight' : [1, 10, 75, 100, 1000]
}

skf = StratifiedKFold(n_splits=5, random_state=42,shuffle=True)

random_search_xgb_rand = RandomizedSearchCV(model_xgb_rand,param_distributions=params_xgb_rand,n_iter=160,cv=skf,scoring='f1_macro',n_jobs=-1)

random_search_xgb_rand.fit(X_train_res,y_train_res)
print(random_search_xgb_rand.best_params_)

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))
# Out:
# {'scale_pos_weight': 1, 'min_child_weight': 1, 'max_depth': 5, 'max_delta_step': 4, 'learning_rate': 0.25, 'gamma': 0.0}
#
#  The Process time taken by the model was 0.03 minutes
#
#  The Real time taken by the model was 0.13 minutes

# %%
start = time.process_time()
real_time = dt.now()

best_xgb = XGBClassifier(**random_search_xgb_rand.best_params_)
best_xgb.fit(X_train_res,y_train_res)

pred_val = best_xgb.predict(X_val)

print(f"Confusion Matrix of Testing Set: \n \n {confusion_matrix(y_val,pred_val)} \n")
print(f"Classification Report of Testing Set: \n \n {classification_report(y_val,pred_val)}")

print('\n The Process time taken by the model was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken by the model was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))

plotly_auc_roc_curve(best_xgb,X_val,y_val)

plotly_precision_recall_curve(best_xgb,X_val,y_val)

plotly_precision_recall_curve2(best_xgb,X_val,y_val)
# Out:
# Confusion Matrix of Testing Set:
#
#  [[148   6]
#  [  7  89]]
#
# Classification Report of Testing Set:
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       154
#            1       0.94      0.93      0.93        96
#
#     accuracy                           0.95       250
#    macro avg       0.95      0.94      0.94       250
# weighted avg       0.95      0.95      0.95       250
#
#
#  The Process time taken by the model was 0.01 minutes
#
#  The Real time taken by the model was 0.0 minutes

# %% [markdown]
# # 8. Conclussions

# %%
start = time.process_time()
real_time = dt.now()

plot_best_models2([log,knn,rfc,xgb],['Logistic Regression','KNeighbors','Random Forest','XGB'],X_test,y_test)

print('\n The Process time taken to create the graphs was {} minutes'.format( round((time.process_time() - start)/60,2) ) )
print('\n The Real time taken to create the graphs was {} minutes'.format( round(((dt.now() - real_time).seconds/60),2)  ))
# Out:
#  The Process time taken to create the graphs was 0.01 minutes
#
#  The Real time taken to create the graphs was 0.0 minutes
